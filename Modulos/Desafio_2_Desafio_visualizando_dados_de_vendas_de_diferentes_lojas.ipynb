# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
lojas = ['A', 'B', 'C', 'D']

vendas_2022 = {'Jan': [100, 80, 150, 50],
    'Fev': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'Mai': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Set': [240, 160, 290, 130],
    'Out': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dez': [300, 350, 400, 250]
}

# %%
df_vendas = pd.DataFrame(vendas_2022, index=lojas)

# %%
fig, axs = plt.subplots(2,2, figsize=(12, 10))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle('Número de vendas das Lojas A, B, C e D ao longo dos meses do ano')

axs[0,0].plot(df_vendas.loc['A'], marker='o', linestyle='-')
axs[0,0].set_title('Loja A')

axs[0,1].plot(df_vendas.loc['B'], marker='o', linestyle='-')
axs[0,1].set_title('Loja B')

axs[1,0].plot(df_vendas.loc['C'], marker='o', linestyle='-')
axs[1,0].set_title('Loja C')

axs[1,1].plot(df_vendas.loc['D'], marker='o', linestyle='-')
axs[1,1].set_title('Loja D')

for ax in axs.flat:
  ax.set(xlabel='Meses', ylabel='Número de Vendas')
  ax.grid()

ymin = 0
ymax = 400
for ax in axs.ravel():
  ax.set_ylim(ymin, ymax)

plt.show()

# %%
# Pedi ao chatgpt uma forma mais simplificada de realizar os gráficos e o mesmo apresentou o código abaixo:
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle('Variação no Número de Vendas em Quatro Lojas ao Longo de 2022', fontsize=16)

meses = df_vendas.columns
lojas = df_vendas.index

for ax, loja in zip(axes.flatten(), lojas):
    ax.plot(meses, df_vendas.loc[loja], marker='o', linestyle='-')
    ax.set_title(f'Loja {loja}')
    ax.set_xlabel('Meses')
    ax.set_ylabel('Vendas')
    ax.grid(True)

ymin = 0
ymax = 400
for ax in axs.ravel():
  ax.set_ylim(ymin, ymax)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
